# %% [markdown]
# # Tarefa 02 — Variáveis, Operações e Prints
#
# Complete as células abaixo. Não apague as instruções — adicione seu código logo abaixo de cada comentário `# SEU CÓDIGO AQUI`.

# %% [markdown]
# ---
# ## Parte 1 — Conversor de Temperatura
#
# Você vai converter uma temperatura em Celsius para Fahrenheit e Kelvin.
#
# **Fórmulas:**
# - Fahrenheit: `F = C × 9/5 + 32`
# - Kelvin: `K = C + 273.15`

# %%
# 1. Crie uma variável chamada celsius com um valor de sua escolha
# SEU CÓDIGO AQUI


# 2. Calcule o valor em Fahrenheit e armazene em uma variável
# SEU CÓDIGO AQUI


# 3. Calcule o valor em Kelvin e armazene em uma variável
# SEU CÓDIGO AQUI


# 4. Exiba os três valores usando print() e f-string
# Exemplo de saída esperada:
# Temperatura: 25°C = 77.0°F = 298.15K
# SEU CÓDIGO AQUI

# %% [markdown]
# **Teste seu conversor** — altere o valor de `celsius` e rode novamente. O resultado muda automaticamente?

# %% [markdown]
# ---
# ## Parte 2 — Calculadora de Média
#
# Você vai calcular a média de três notas e exibir o resultado formatado.

# %%
# 1. Crie três variáveis: nota1, nota2, nota3
# Use valores entre 0 e 10
# SEU CÓDIGO AQUI


# 2. Calcule a média e armazene em uma variável chamada media
# SEU CÓDIGO AQUI


# 3. Exiba o resultado usando print() e f-string
# Exemplo de saída esperada:
# Notas: 8.0 | 7.5 | 9.0
# Média final: 8.17
# SEU CÓDIGO AQUI

# %% [markdown]
# ---
# ## Desafio opcional
#
# Calcule o preço final de um produto após aplicar um desconto percentual.
#
# Escolha o preço original e o percentual de desconto. Depois exiba o valor do desconto e o preço final.

# %%
# 1. Crie as variáveis preco_original e percentual_desconto
# SEU CÓDIGO AQUI


# 2. Calcule o valor do desconto e o preço final
# SEU CÓDIGO AQUI


# 3. Exiba os valores usando print() e f-string
# Exemplo de saída esperada:
# Preço original: R$ 150.00
# Desconto (10%): R$ 15.00
# Preço final: R$ 135.00
# SEU CÓDIGO AQUI
